# %% [markdown]
# #Подключаем DataSet

# %% [markdown]
# Подключаем необходимые библиотеки

# %%
import zipfile                 # для работы с zip
import os                      # для работы с файловой системой

from google.colab import drive # для работы с диском
from PIL import Image          # для работы с изображениями

# %% [markdown]
# Подключаем Диск

# %%
drive.mount('/content/drive')

# %% [markdown]
# Распакуем датасет

# %%
# !unzip '/content/datase.zip.zip' - d '/content/drive/My Drive/data'

# %% [markdown]
# #ELM на базе клеточного автомата

# %% [markdown]
# Для начала переведём изображения из .jpg в .tiff, то есть растровый формат.

# %%
#перевод изображения

# %% [markdown]
# Теперь переведём изображения в шкалу GrayScale, получим начальную конфигурацию

# %%
#перевод изображения

# %% [markdown]
# Применим сглаживание Гаусса и получим конечную конфигурацию

# %%
#метод Гаусса
import cv2
import matplotlib.pyplot


kernel = (7, 7)
imgs = {
    "picture": cv2.imread("train[]")
}

imgs["gauss_blur"] = cv2.GaussianBlur(imgs["picture"], kernel, 1)

# %% [markdown]
# Задаем ELM: вес - произвольный, на вход информация о клетке и всех ее соседях по стороне/углу

# %% [markdown]
# Количество скрытых узлов - N

# %% [markdown]
# На выход вектор (1, 0) или (0, 1) - граница (черная) / не граница (белая)

# %% [markdown]
# Тренировка осуществляется засчет каркаса TenserFlow

# %%
()
